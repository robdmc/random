# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the Rosenbrock function
def rosenbrock(x, y):
    return (1 - x)**2 + 100 * (y - x**2)**2

# Generate data
x = np.linspace(-4, 4, 1000)
y = np.linspace(-3, 5, 1000)
X, Y = np.meshgrid(x, y)
Z = rosenbrock(X, Y)
Z = np.log(1e-3 + Z)

# Plotting
fig = plt.figure(figsize=(8, 6))

cmap = 'viridis'
# cmap = 'magma'
plt.imshow(Z, extent=[-4, 4, -3, 5], origin='lower', cmap=cmap)
plt.colorbar(label='Rosenbrock Function Value')
plt.title('Colored Image Plot of Rosenbrock Function')
plt.xlabel('x')
plt.ylabel('y')
ax = fig.axes[0]
ax.plot([0, 1], [0, 1], '.', color='magenta')
# plt.show()

# %%
type(fig.axes[0])
# Out:
# matplotlib.axes._axes.Axes
